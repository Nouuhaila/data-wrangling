# %% [markdown]
# ## Report: act_report

# %% [markdown]
# # Introduction

# %% [markdown]
# ### Real-world data rarely comes clean. Using Python and its libraries, we gather data from a variety of sources and in a variety of formats, assess its quality and tidiness, then clean it. This is called data wrangling.
# WeRateDogs is a Twitter account that rates people's dogs with a humorous comment about the dog. These ratings almost always have a denominator of 10.  WeRateDogs has over 4 million followers and has received international media coverage.

# %% [markdown]
# # Analysis and Visualisation

# %% [markdown]
# After Gathering ,Assessing and Cleaning Data .I have done some visualisation to give us a clear idea of what the information means by giving it visual context through maps or graphs.

# %%
import pandas as pd
import numpy as np
import requests
import json
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
data=pd.read_csv('twitter_archive_master.csv')

# %%
data.name.value_counts()[0:6].plot('barh', figsize=(15,8), title='Most Common Dog Names').set_xlabel("Number of Dogs");

# %% [markdown]
# ## Dog name commonality
#
# The first six dog names are :
# Cooper , Charlie , Oliver , Sadie ,Koda ,Tucker

# %%
sns.set(rc={'figure.figsize':(10,10)}, style="dark")
sns.regplot(x='favorite_count', y='retweet_count', data=data)

plt.title("Favorite counts vs Retweet counts",color="b", size=20)
plt.xlabel("Favorite Counts", size=10)
plt.ylabel("Retweet Counts", size=10)

corr= data.corr()

print("The Correlation Between retweet counts and favorite counts is ",corr.loc['favorite_count','retweet_count']);
# Out:
# The Correlation Between retweet counts and favorite counts is  0.916518249405

# %% [markdown]
# ## Favorite Vs Retweet counts
#
# There is a positive correlation between Favorite (like) counts and how much a post was retweeted .
# This correlation is very important to increase users traffic on the page .

# %% [markdown]
# # Conclusion

# %% [markdown]
# This write up offers a straightforward look at the data wrangling process .
# There is so much more that can be done with this data set.
